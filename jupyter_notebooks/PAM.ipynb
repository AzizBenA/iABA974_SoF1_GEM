# %%
# %pip install PAModelpy

# %% [markdown]
# This jupyter notebook will be used for the creation of the PAM model of SOF1

# %%
#importing the packages
import os
import PAModelpy
from cobra.io import read_sbml_model
import pandas as pd

#load PAMpy modules
from PAModelpy.EnzymeSectors import ActiveEnzymeSector, TransEnzymeSector, UnusedEnzymeSector
from PAModelpy.PAModel import PAModel
from PAModelpy.PAMValidator import PAMValidator
from PAModelpy.configuration import Config

from PAModelpy.utils import (merge_enzyme_complexes, parse_reaction2protein, _get_genes_for_proteins)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 #importing the packages
#       2 import os
# ----> 3 import PAModelpy
#       4 from cobra.io import read_sbml_model
#       5 import pandas as pd
#
# ModuleNotFoundError: No module named 'PAModelpy'
